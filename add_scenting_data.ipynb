# %% [markdown]
# **Add scenting data to "measurements.json" for each experimental set of params.**

# %% [markdown]
# See current "measurements.json", get "position_history" key.

# %%
import json

# %%
file = "/Users/dieumynguyen/Desktop/Projects/bee_communication/experiments/06M_02D-17H_41M_47S/experiment0_Q0.15_W0.4_D0.35_T0.4_wb1/data/measurements.json"

# %%
with open(file, 'r') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['distance_from_queen', 'concentration_history', 'position_history', 'distance_from_others'])

# %%
data['position_history'].keys()
# Out:
# dict_keys(['queen', 'worker_1', 'worker_2', 'worker_3', 'worker_4', 'worker_5', 'worker_6', 'worker_7', 'worker_8', 'worker_9', 'worker_10', 'worker_11', 'worker_12', 'worker_13', 'worker_14', 'worker_15', 'worker_16', 'worker_17', 'worker_18', 'worker_19', 'worker_20', 'worker_21', 'worker_22', 'worker_23', 'worker_24', 'worker_25', 'worker_26', 'worker_27', 'worker_28', 'worker_29', 'worker_30', 'worker_31', 'worker_32', 'worker_33', 'worker_34', 'worker_35', 'worker_36', 'worker_37', 'worker_38', 'worker_39', 'worker_40', 'worker_41', 'worker_42', 'worker_43', 'worker_44', 'worker_45', 'worker_46', 'worker_47', 'worker_48', 'worker_49', 'worker_50'])

# %%
[data['position_history']['worker_50'][i]["scenting"] for i in range(80)]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
len(data['position_history']['worker_1'])
# Out:
# 80

# %% [markdown]
# A worker should only be scenting (scenting =  True) for 6 timesteps.

# %%
data['position_history']['worker_30']
# Out:
# [{'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.7286362665367716,
#   'y': -1.048018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.7286362665367716,
#   'y': -1.058018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.718636266536772,
#   'y': -1.058018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.718636266536772,
#   'y': -1.068018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.668636266536772,
#   'y': -1.068018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.688636266536772,
#   'y': -1.068018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.688636266536772,
#   'y': -1.078018015420414},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -2.688636266536772,
#   'y': -1.058018015420414},
#  {'found_queen_direction': False,
# ...
