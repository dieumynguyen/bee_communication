# %%
import itertools
import json

# %%
queen_bee_concentrations = [0.15]
worker_bee_concentrations = [0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.3, 0.5]
diffusion_coefficients = [0.05, 0.15, 0.25, 0.35, 0.45, 0.55]
worker_bee_thresholds = [0.005, 0.5]

for i, combination in enumerate(itertools.product(queen_bee_concentrations, worker_bee_concentrations, diffusion_coefficients, worker_bee_thresholds)):
    print(i, combination)
# Out:
# 0 (0.15, 0.0005, 0.05, 0.005)
# 1 (0.15, 0.0005, 0.05, 0.5)
# 2 (0.15, 0.0005, 0.15, 0.005)
# 3 (0.15, 0.0005, 0.15, 0.5)
# 4 (0.15, 0.0005, 0.25, 0.005)
# 5 (0.15, 0.0005, 0.25, 0.5)
# 6 (0.15, 0.0005, 0.35, 0.005)
# 7 (0.15, 0.0005, 0.35, 0.5)
# 8 (0.15, 0.0005, 0.45, 0.005)
# 9 (0.15, 0.0005, 0.45, 0.5)
# 10 (0.15, 0.0005, 0.55, 0.005)
# 11 (0.15, 0.0005, 0.55, 0.5)
# 12 (0.15, 0.001, 0.05, 0.005)
# 13 (0.15, 0.001, 0.05, 0.5)
# 14 (0.15, 0.001, 0.15, 0.005)
# 15 (0.15, 0.001, 0.15, 0.5)
# 16 (0.15, 0.001, 0.25, 0.005)
# 17 (0.15, 0.001, 0.25, 0.5)
# 18 (0.15, 0.001, 0.35, 0.005)
# 19 (0.15, 0.001, 0.35, 0.5)
# 20 (0.15, 0.001, 0.45, 0.005)
# 21 (0.15, 0.001, 0.45, 0.5)
# 22 (0.15, 0.001, 0.55, 0.005)
# 23 (0.15, 0.001, 0.55, 0.5)
# 24 (0.15, 0.005, 0.05, 0.005)
# 25 (0.15, 0.005, 0.05, 0.5)
# 26 (0.15, 0.005, 0.15, 0.005)
# 27 (0.15, 0.005, 0.15, 0.5)
# 28 (0.15, 0.005, 0.25, 0.005)
# 29 (0.15, 0.005, 0.25, 0.5)
# 30 (0.15, 0.005, 0.35, 0.005)
# 31 (0.15, 0.005, 0.35, 0.5)
# ...

# %%
# See if bias_x, bias_y are saved
file = "/Users/dieumynguyen/Desktop/Projects/bee_communication/experiments/06M_11D-11H_37M_42S/experiment0_Q0.15_W0.5_D0.55_T0.005_wb1/data/measurements.json"
with open(file, 'r') as f:
    data = json.load(f)
    
data.keys()
# Out:
# dict_keys(['distance_from_queen', 'concentration_history', 'position_history', 'distance_from_others'])

# %%
len(data["position_history"])
# Out:
# 51

# %%
data["position_history"]["worker_2"]
# Out:
# [{'bias_x': 0.25,
#   'bias_y': 0.9682458365518543,
#   'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.99465584480253,
#   'y': -1.725965335930343},
#  {'bias_x': 0.7071067806865474,
#   'bias_y': -0.7071067806865474,
#   'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.98465584480253,
#   'y': -1.725965335930343},
#  {'bias_x': 0.7071067806865474,
#   'bias_y': -0.7071067806865474,
#   'found_queen_direction': False,
#   'scenting': False,
#   'x': 2.00465584480253,
#   'y': -1.725965335930343},
#  {'bias_x': 0.7071067806865474,
#   'bias_y': -0.7071067806865474,
#   'found_queen_direction': False,
#   'scenting': False,
#   'x': 2.00465584480253,
#   'y': -1.685965335930343},
#  {'bias_x': 0.7071067806865474,
#   'bias_y': -0.7071067806865474,
#   'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.9646558448025297,
#   'y': -1.685965335930343},
#  {'bias_x': 0.7071067806865474,
#   'bias_y': -0.7071067806865474,
# ...
