# %% [markdown]
# **Add scenting data to "measurements.json" for each experimental set of params.**

# %% [markdown]
# See current "measurements.json", get "position_history" key.

# %%
import json

# %%
file = "/Users/dieumynguyen/Desktop/Projects/bee_communication/experiments/06M_01D-17H_16M_03S/experiment0/data/measurements.json"

# %%
with open(file, 'r') as f:
    data = json.load(f)

# %%
data['position_history'].keys()
# Out:
# dict_keys(['queen', 'worker_1', 'worker_2', 'worker_3', 'worker_4', 'worker_5', 'worker_6', 'worker_7', 'worker_8', 'worker_9', 'worker_10', 'worker_11', 'worker_12', 'worker_13', 'worker_14', 'worker_15', 'worker_16', 'worker_17', 'worker_18', 'worker_19', 'worker_20', 'worker_21', 'worker_22', 'worker_23', 'worker_24', 'worker_25', 'worker_26', 'worker_27', 'worker_28', 'worker_29', 'worker_30', 'worker_31', 'worker_32', 'worker_33', 'worker_34', 'worker_35', 'worker_36', 'worker_37', 'worker_38', 'worker_39', 'worker_40', 'worker_41', 'worker_42', 'worker_43', 'worker_44', 'worker_45', 'worker_46', 'worker_47', 'worker_48', 'worker_49', 'worker_50'])

# %%
data['position_history']['worker_1']
# Out:
# [{'found_queen_direction': False,
#   'x': -0.752759286915825,
#   'y': 2.704285838459497},
#  {'found_queen_direction': False,
#   'x': -0.7927592869158251,
#   'y': 2.704285838459497},
#  {'found_queen_direction': False,
#   'x': -0.7927592869158251,
#   'y': 2.744285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8027592869158251,
#   'y': 2.744285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8127592869158251,
#   'y': 2.744285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8127592869158251,
#   'y': 2.7142858384594972},
#  {'found_queen_direction': False,
#   'x': -0.8127592869158251,
#   'y': 2.694285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8227592869158251,
#   'y': 2.694285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8727592869158252,
#   'y': 2.694285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8727592869158252,
#   'y': 2.724285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8727592869158252,
#   'y': 2.694285838459497},
#  {'found_queen_direction': False,
#   'x': -0.8727592869158252,
#   'y': 2.674285838459497},
#  {'found_queen_direction': False,
#   'x': -0.9127592869158252,
#   'y': 2.674285838459497},
#  {'found_queen_direction': False,
#   'x': -0.9127592869158252,
#   'y': 2.6242858384594974},
#  {'found_queen_direction': False,
#   'x': -0.9627592869158252,
#   'y': 2.6242858384594974},
#  {'found_queen_direction': False,
#   'x': -0.9627592869158252,
#   'y': 2.6642858384594974},
#  {'found_queen_direction': False,
#   'x': -0.9627592869158252,
#   'y': 2.6142858384594976},
#  {'found_queen_direction': False,
#   'x': -1.0127592869158253,
#   'y': 2.6142858384594976},
#  {'found_queen_direction': False,
#   'x': -1.0027592869158253,
#   'y': 2.6142858384594976},
#  {'found_queen_direction': False,
#   'x': -1.0027592869158253,
#   'y': 2.6242858384594974},
#  {'found_queen_direction': False,
#   'x': -1.0027592869158253,
#   'y': 2.674285838459497},
#  {'found_queen_direction': False,
#   'x': -0.9627592869158252,
#   'y': 2.674285838459497},
#  {'found_queen_direction': False,
#   'x': -0.9627592869158252,
#   'y': 2.6442858384594974},
#  {'found_queen_direction': False,
#   'x': -1.0127592869158253,
#   'y': 2.6442858384594974},
#  {'found_queen_direction': False,
#   'x': -1.0127592869158253,
#   'y': 2.694285838459497},
#  {'found_queen_direction': False,
#   'x': -1.0127592869158253,
#   'y': 2.6642858384594974},
#  {'found_queen_direction': False,
#   'x': -0.9927592869158253,
#   'y': 2.6642858384594974},
#  {'found_queen_direction': False,
#   'x': -0.9927592869158253,
#   'y': 2.6342858384594976},
#  {'found_queen_direction': False,
#   'x': -1.0427592869158253,
#   'y': 2.6342858384594976},
#  {'found_queen_direction': False,
#   'x': -1.0427592869158253,
#   'y': 2.5842858384594978},
#  {'found_queen_direction': False,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.574285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0627592869158253,
#   'y': 2.554285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0727592869158253,
#   'y': 2.544285838459498},
#  {'found_queen_direction': True,
#   'x': -1.0827592869158253,
#   'y': 2.5342858384594984},
#  {'found_queen_direction': True,
#   'x': -1.1027592869158254,
#   'y': 2.5142858384594984},
#  {'found_queen_direction': True,
#   'x': -1.1127592869158254,
#   'y': 2.5042858384594986},
#  {'found_queen_direction': True,
#   'x': -1.1427592869158254,
#   'y': 2.474285838459499},
#  {'found_queen_direction': True,
#   'x': -1.1527592869158254,
#   'y': 2.464285838459499},
#  {'found_queen_direction': True,
#   'x': -1.1627592869158254,
#   'y': 2.454285838459499},
#  {'found_queen_direction': True,
#   'x': -1.1527592869158254,
#   'y': 2.4442858384594994},
#  {'found_queen_direction': True,
#   'x': -1.1427592869158254,
#   'y': 2.4342858384594996},
#  {'found_queen_direction': True,
#   'x': -1.1327592869158254,
#   'y': 2.4242858384595},
#  {'found_queen_direction': True,
#   'x': -1.1127592869158254,
#   'y': 2.4042858384595},
#  {'found_queen_direction': True,
#   'x': -1.0827592869158253,
#   'y': 2.3742858384595},
#  {'found_queen_direction': True,
#   'x': -1.0627592869158253,
#   'y': 2.3542858384595},
#  {'found_queen_direction': True,
#   'x': -1.0427592869158253,
#   'y': 2.3342858384595},
#  {'found_queen_direction': True,
#   'x': -1.0327592869158253,
#   'y': 2.3442858384595},
#  {'found_queen_direction': True,
#   'x': -1.0127592869158253,
#   'y': 2.3642858384595},
#  {'found_queen_direction': True,
#   'x': -0.9927592869158253,
#   'y': 2.3842858384595},
#  {'found_queen_direction': True,
#   'x': -0.9627592869158252,
#   'y': 2.4142858384594996},
#  {'found_queen_direction': True,
#   'x': -0.9427592869158252,
#   'y': 2.4342858384594996},
#  {'found_queen_direction': True,
#   'x': -0.9227592869158252,
#   'y': 2.4542858384594997},
#  {'found_queen_direction': True,
#   'x': -0.9127592869158252,
#   'y': 2.4642858384594994},
#  {'found_queen_direction': True,
#   'x': -0.9027592869158252,
#   'y': 2.4742858384594992},
#  {'found_queen_direction': True,
#   'x': -0.8727592869158252,
#   'y': 2.504285838459499},
#  {'found_queen_direction': True,
#   'x': -0.8627592869158252,
#   'y': 2.514285838459499},
#  {'found_queen_direction': True,
#   'x': -0.8527592869158251,
#   'y': 2.5242858384594986},
#  {'found_queen_direction': True,
#   'x': -0.8427592869158251,
#   'y': 2.5342858384594984},
#  {'found_queen_direction': True,
#   'x': -0.8327592869158251,
#   'y': 2.544285838459498},
#  {'found_queen_direction': True,
#   'x': -0.8227592869158251,
#   'y': 2.554285838459498},
#  {'found_queen_direction': True,
#   'x': -0.8127592869158251,
#   'y': 2.5642858384594978},
#  {'found_queen_direction': True,
#   'x': -0.8027592869158251,
#   'y': 2.5742858384594975},
#  {'found_queen_direction': True,
#   'x': -0.7827592869158251,
#   'y': 2.5942858384594976},
#  {'found_queen_direction': True,
#   'x': -0.7727592869158251,
#   'y': 2.6042858384594973},
#  {'found_queen_direction': True,
#   'x': -0.752759286915825,
#   'y': 2.6242858384594974},
#  {'found_queen_direction': True,
#   'x': -0.732759286915825,
#   'y': 2.6442858384594974},
#  {'found_queen_direction': True,
#   'x': -0.722759286915825,
#   'y': 2.654285838459497},
#  {'found_queen_direction': True,
#   'x': -0.702759286915825,
#   'y': 2.674285838459497},
#  {'found_queen_direction': True,
#   'x': -0.692759286915825,
#   'y': 2.684285838459497},
#  {'found_queen_direction': True,
#   'x': -0.682759286915825,
#   'y': 2.6942858384594968},
#  {'found_queen_direction': True,
#   'x': -0.662759286915825,
#   'y': 2.714285838459497},
#  {'found_queen_direction': True,
#   'x': -0.642759286915825,
#   'y': 2.734285838459497},
#  {'found_queen_direction': True,
#   'x': -0.632759286915825,
#   'y': 2.7442858384594966},
#  {'found_queen_direction': True,
#   'x': -0.6027592869158249,
#   'y': 2.7742858384594964},
#  {'found_queen_direction': True,
#   'x': -0.5827592869158249,
#   'y': 2.7942858384594964},
#  {'found_queen_direction': True,
#   'x': -0.5627592869158249,
#   'y': 2.8142858384594964},
#  {'found_queen_direction': True,
#   'x': -0.5427592869158249,
#   'y': 2.8342858384594964},
#  {'found_queen_direction': True,
#   'x': -0.5227592869158249,
#   'y': 2.8542858384594965},
#  {'found_queen_direction': True,
#   'x': -0.5127592869158248,
#   'y': 2.8642858384594962},
#  {'found_queen_direction': True,
#   'x': -0.4927592869158248,
#   'y': 2.8842858384594963},
#  {'found_queen_direction': True,
#   'x': -0.4827592869158248,
#   'y': 2.894285838459496},
#  {'found_queen_direction': True,
#   'x': -0.4527592869158248,
#   'y': 2.924285838459496},
#  {'found_queen_direction': True,
#   'x': -0.43275928691582477,
#   'y': 2.944285838459496},
#  {'found_queen_direction': True,
#   'x': -0.42275928691582476,
#   'y': 2.9542858384594957},
#  {'found_queen_direction': True,
#   'x': -0.41275928691582475,
#   'y': 2.9642858384594954},
#  {'found_queen_direction': True,
#   'x': -0.39275928691582473,
#   'y': 2.9842858384594955},
#  {'found_queen_direction': True,
#   'x': -0.3827592869158247,
#   'y': 2.9942858384594953},
#  {'found_queen_direction': True, 'x': -0.3727592869158247, 'y': 3},
#  {'found_queen_direction': True, 'x': -0.3527592869158247, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.3227592869158247, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.31275928691582466, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.28275928691582464, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.2527592869158246, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.23275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.20275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.17275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.1627592869158246, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.14275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.12275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.11275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.09275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.06275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.05275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.03275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': -0.02275928691582462, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.007240713084175378, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.027240713084175378, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.04724071308417538, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.07724071308417538, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.08724071308417537, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.09724071308417537, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.10724071308417536, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.13724071308417535, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.16724071308417535, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.17724071308417536, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.19724071308417535, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.21724071308417534, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.23724071308417533, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.24724071308417533, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.25724071308417534, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.26724071308417535, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.28724071308417537, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.31724071308417534, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.34724071308417537, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.3672407130841754, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.3972407130841754, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.41724071308417543, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.42724071308417544, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.43724071308417545, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.45724071308417547, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.4672407130841755, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.4872407130841755, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.5072407130841755, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.5172407130841755, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.5372407130841755, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.5672407130841756, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.5872407130841756, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.6072407130841756, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.6372407130841756, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.6672407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.6872407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.7172407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.7272407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.7472407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.7772407130841757, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.7972407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.8172407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.8272407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.8472407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.8672407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.8772407130841758, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.9072407130841759, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.9372407130841759, 'y': 3.0},
#  {'found_queen_direction': True, 'x': 0.9472407130841759, 'y': 3.0}]

# %%
len(data['position_history']['worker_1'])
# Out:
# 160

# %% [markdown]
# A worker should only be scenting (scenting =  True) for 6 timesteps.
