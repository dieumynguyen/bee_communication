# %% [markdown]
# **Add scenting data to "measurements.json" for each experimental set of params.**

# %% [markdown]
# See current "measurements.json", get "position_history" key.

# %%
import json

# %%
file = "/Users/dieumynguyen/Desktop/Projects/bee_communication/experiments/06M_02D-16H_16M_10S/experiment0_Q0.15_W0.4_D0.35_T0.4_wb1/data/measurements.json"

# %%
with open(file, 'r') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['distance_from_queen', 'concentration_history', 'position_history', 'distance_from_others'])

# %%
data['position_history'].keys()
# Out:
# dict_keys(['queen', 'worker_1', 'worker_2', 'worker_3', 'worker_4', 'worker_5', 'worker_6', 'worker_7', 'worker_8', 'worker_9', 'worker_10', 'worker_11', 'worker_12', 'worker_13', 'worker_14', 'worker_15', 'worker_16', 'worker_17', 'worker_18', 'worker_19', 'worker_20', 'worker_21', 'worker_22', 'worker_23', 'worker_24', 'worker_25', 'worker_26', 'worker_27', 'worker_28', 'worker_29', 'worker_30', 'worker_31', 'worker_32', 'worker_33', 'worker_34', 'worker_35', 'worker_36', 'worker_37', 'worker_38', 'worker_39', 'worker_40', 'worker_41', 'worker_42', 'worker_43', 'worker_44', 'worker_45', 'worker_46', 'worker_47', 'worker_48', 'worker_49', 'worker_50'])

# %%
data['position_history']['worker_20']
# Out:
# [{'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.1053981590729416,
#   'y': -0.3590850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.1053981590729416,
#   'y': -0.4090850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.0753981590729416,
#   'y': -0.4090850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.0953981590729416,
#   'y': -0.4090850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.0953981590729416,
#   'y': -0.44908503756239215},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.0553981590729415,
#   'y': -0.44908503756239215},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 1.0053981590729415,
#   'y': -0.44908503756239215},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.9853981590729415,
#   'y': -0.44908503756239215},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.9353981590729414,
#   'y': -0.44908503756239215},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.9353981590729414,
#   'y': -0.45908503756239216},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8953981590729414,
#   'y': -0.45908503756239216},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8653981590729414,
#   'y': -0.45908503756239216},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8653981590729414,
#   'y': -0.4790850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8653981590729414,
#   'y': -0.5090850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8653981590729414,
#   'y': -0.4790850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8653981590729414,
#   'y': -0.46908503756239217},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8453981590729414,
#   'y': -0.46908503756239217},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8453981590729414,
#   'y': -0.4790850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8453981590729414,
#   'y': -0.5090850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8453981590729414,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.47908503756239224},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.8053981590729413,
#   'y': -0.5190850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.7753981590729413,
#   'y': -0.5490850375623922},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.7453981590729413,
#   'y': -0.5790850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.7253981590729413,
#   'y': -0.5990850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.7053981590729412,
#   'y': -0.6190850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.6953981590729412,
#   'y': -0.6290850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.6853981590729412,
#   'y': -0.6390850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.6553981590729412,
#   'y': -0.6690850375623923},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.6253981590729412,
#   'y': -0.6990850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.6153981590729412,
#   'y': -0.7090850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5853981590729411,
#   'y': -0.7390850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5753981590729411,
#   'y': -0.7490850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5553981590729411,
#   'y': -0.7690850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5453981590729411,
#   'y': -0.7790850375623924},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5253981590729411,
#   'y': -0.7990850375623925},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.5053981590729411,
#   'y': -0.8190850375623925},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.47539815907294103,
#   'y': -0.8490850375623925},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.445398159072941,
#   'y': -0.8790850375623925},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.415398159072941,
#   'y': -0.9090850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.40539815907294097,
#   'y': -0.9190850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.39539815907294096,
#   'y': -0.9290850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.36539815907294093,
#   'y': -0.9590850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.3553981590729409,
#   'y': -0.9690850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.3453981590729409,
#   'y': -0.9790850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.3153981590729409,
#   'y': -1.0090850375623925},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.29539815907294087,
#   'y': -1.0290850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.26539815907294084,
#   'y': -1.0590850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.25539815907294083,
#   'y': -1.0690850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.23539815907294084,
#   'y': -1.0890850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.22539815907294083,
#   'y': -1.0990850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.19539815907294084,
#   'y': -1.1290850375623926},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.16539815907294084,
#   'y': -1.1590850375623927},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.13539815907294084,
#   'y': -1.1890850375623927},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.10539815907294084,
#   'y': -1.2190850375623927},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.09539815907294084,
#   'y': -1.2290850375623927},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.06539815907294085,
#   'y': -1.2590850375623928},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.04539815907294084,
#   'y': -1.2790850375623928},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.02539815907294084,
#   'y': -1.2990850375623928},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.04539815907294084,
#   'y': -1.3190850375623928},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.07539815907294084,
#   'y': -1.3490850375623928},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.09539815907294084,
#   'y': -1.3690850375623929},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.11539815907294085,
#   'y': -1.3890850375623929},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.14539815907294085,
#   'y': -1.419085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.15539815907294086,
#   'y': -1.429085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.16539815907294086,
#   'y': -1.439085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.18539815907294085,
#   'y': -1.459085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.19539815907294086,
#   'y': -1.469085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.22539815907294086,
#   'y': -1.499085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.25539815907294083,
#   'y': -1.529085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.26539815907294084,
#   'y': -1.539085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.28539815907294086,
#   'y': -1.559085037562393},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': 0.3153981590729409,
#   'y': -1.589085037562393}]

# %%
len(data['position_history']['worker_1'])
# Out:
# 80

# %% [markdown]
# A worker should only be scenting (scenting =  True) for 6 timesteps.
