# %% [markdown]
# ### Plot number of scenting bees over time

# %%
# Imports
import json
import numpy as np
import plotly.plotly as py
import matplotlib as mpl
mpl.use('Agg')
# %matplotlib inline
from matplotlib import cycler
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import os
import glob2
import re

# %%
with open("combined_replicates/Q0.15_W0.4_D0.2_T0.005_wb1.json", "r") as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 20

# %%
position_data = data[0]['Replicate 1']['position_history']

# %%
len(position_data)
# Out:
# 51

# %%
position_data["worker_1"]
# Out:
# [{'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6795879221967756,
#   'y': 1.569063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6795879221967756,
#   'y': 1.609063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 1.609063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 1.599063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 1.559063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 1.539063790304833},
#  {'found_queen_direction': False,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': True,
#   'x': -0.6995879221967756,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7095879221967756,
#   'y': 1.489063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7295879221967756,
#   'y': 1.469063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7395879221967756,
#   'y': 1.459063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7495879221967756,
#   'y': 1.449063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7695879221967756,
#   'y': 1.4290637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7895879221967756,
#   'y': 1.4090637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7995879221967757,
#   'y': 1.3990637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8195879221967757,
#   'y': 1.3790637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8495879221967757,
#   'y': 1.3490637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8795879221967757,
#   'y': 1.3790637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9095879221967758,
#   'y': 1.4090637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9395879221967758,
#   'y': 1.439063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9495879221967758,
#   'y': 1.4290637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9595879221967758,
#   'y': 1.4190637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9795879221967758,
#   'y': 1.3990637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9895879221967758,
#   'y': 1.3890637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0195879221967759,
#   'y': 1.3590637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0395879221967759,
#   'y': 1.3390637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.069587922196776,
#   'y': 1.3090637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.099587922196776,
#   'y': 1.2790637903048327},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.109587922196776,
#   'y': 1.2790637903048327},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.139587922196776,
#   'y': 1.3090637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.149587922196776,
#   'y': 1.3190637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.179587922196776,
#   'y': 1.3490637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.199587922196776,
#   'y': 1.3690637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.219587922196776,
#   'y': 1.3890637903048328},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.229587922196776,
#   'y': 1.3990637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.239587922196776,
#   'y': 1.4090637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.249587922196776,
#   'y': 1.4190637903048329},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.269587922196776,
#   'y': 1.439063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.299587922196776,
#   'y': 1.469063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3295879221967761,
#   'y': 1.499063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3495879221967761,
#   'y': 1.519063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3795879221967762,
#   'y': 1.549063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3595879221967762,
#   'y': 1.569063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3295879221967761,
#   'y': 1.599063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3195879221967761,
#   'y': 1.609063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.309587922196776,
#   'y': 1.619063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.289587922196776,
#   'y': 1.639063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.269587922196776,
#   'y': 1.659063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.249587922196776,
#   'y': 1.679063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.219587922196776,
#   'y': 1.7090637903048331},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.189587922196776,
#   'y': 1.7390637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.169587922196776,
#   'y': 1.7590637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.139587922196776,
#   'y': 1.7890637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.129587922196776,
#   'y': 1.7990637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.119587922196776,
#   'y': 1.8090637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.109587922196776,
#   'y': 1.8190637903048332},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.079587922196776,
#   'y': 1.8490637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0495879221967759,
#   'y': 1.8790637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0395879221967759,
#   'y': 1.8890637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0195879221967759,
#   'y': 1.9090637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0095879221967758,
#   'y': 1.9190637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9895879221967758,
#   'y': 1.9390637903048333},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9595879221967758,
#   'y': 1.9690637903048334},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9495879221967758,
#   'y': 1.9790637903048334},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9295879221967758,
#   'y': 1.9990637903048334},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8995879221967757,
#   'y': 2.0290637903048334},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8695879221967757,
#   'y': 2.059063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8595879221967757,
#   'y': 2.069063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8395879221967757,
#   'y': 2.089063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8095879221967757,
#   'y': 2.119063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7895879221967756,
#   'y': 2.139063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7695879221967756,
#   'y': 2.159063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7495879221967756,
#   'y': 2.179063790304833},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7395879221967756,
#   'y': 2.1890637903048327},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7295879221967756,
#   'y': 2.1990637903048325},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6995879221967756,
#   'y': 2.2290637903048323},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6795879221967756,
#   'y': 2.2490637903048323},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6495879221967755,
#   'y': 2.279063790304832},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6395879221967755,
#   'y': 2.289063790304832},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6095879221967755,
#   'y': 2.3190637903048317},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5895879221967755,
#   'y': 2.3390637903048317},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5595879221967754,
#   'y': 2.3690637903048315},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5395879221967754,
#   'y': 2.3890637903048315},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5195879221967754,
#   'y': 2.4090637903048315},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5095879221967754,
#   'y': 2.4190637903048313},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.4995879221967754,
#   'y': 2.429063790304831},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.4795879221967754,
#   'y': 2.449063790304831},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.46958792219677536,
#   'y': 2.459063790304831},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.43958792219677534,
#   'y': 2.4890637903048307},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.4095879221967753,
#   'y': 2.5190637903048305},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.3795879221967753,
#   'y': 2.5490637903048303},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.34958792219677526,
#   'y': 2.57906379030483},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.32958792219677524,
#   'y': 2.59906379030483},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.2995879221967752,
#   'y': 2.62906379030483},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.32958792219677524,
#   'y': 2.6590637903048298},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.34958792219677526,
#   'y': 2.6790637903048298},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.3795879221967753,
#   'y': 2.7090637903048296},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.3995879221967753,
#   'y': 2.7290637903048296},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.42958792219677533,
#   'y': 2.7590637903048294},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.45958792219677536,
#   'y': 2.789063790304829},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.46958792219677536,
#   'y': 2.799063790304829},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.4995879221967754,
#   'y': 2.829063790304829},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5195879221967754,
#   'y': 2.849063790304829},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5295879221967754,
#   'y': 2.8590637903048286},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5595879221967754,
#   'y': 2.8890637903048284},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5795879221967755,
#   'y': 2.9090637903048284},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.5995879221967755,
#   'y': 2.9290637903048284},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6295879221967755,
#   'y': 2.9590637903048282},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6495879221967755,
#   'y': 2.9790637903048283},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6595879221967755,
#   'y': 2.989063790304828},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6795879221967756,
#   'y': 3},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.6895879221967756,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7095879221967756,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7395879221967756,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7595879221967756,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.7895879221967756,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8095879221967757,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8295879221967757,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8495879221967757,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.8795879221967757,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9095879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9295879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9495879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9595879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9695879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9895879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -0.9995879221967758,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0195879221967759,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0495879221967759,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.0595879221967759,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.089587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.109587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.129587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.139587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.149587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.159587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.169587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.189587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.209587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.229587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.239587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.249587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.259587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.269587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.279587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.299587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.309587922196776,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3395879221967761,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3595879221967762,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.3895879221967762,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.4095879221967762,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.4395879221967762,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.4495879221967762,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.4795879221967763,
#   'y': 3.0},
#  {'found_queen_direction': True,
#   'scenting': False,
#   'x': -1.5095879221967763,
#   'y': 3.0}]

# %% [markdown]
# ### Load in JSON from combine_replicates.py and pull out position_history data

# %%
def get_position_data(param_set_json):

    ''' Load in each JSON created by combine_replicates.py and position_history data '''

    with open("combined_replicates/" + param_set_json, "r") as f:
        data = json.load(f)

    sample_length = len(data[0]["Replicate {}".format(1)]["position_history"])

    all_distances = {}
    for j in range(len(data)):  # Loop over each replicate
        #avg_distance = []
        #for i in range(sample_length):    # Loop over all the 160 averages/values/lists
        
        # Loop over 50 workers
        for i in range(1, 51):
            position = data[j]["Replicate {}".format(j+1)]["position_history"]["worker_{}".format(i)]
            all_distances["worker_{}".format(i)] = position


    # Write truncated data to JSON
    start_char = "j"
    filename = f.name
    name = filename[20:filename.index(start_char)]

    with open('position_data/{}json'.format(name), 'w') as outfile:
        json.dump(all_distances, outfile)

    return None

# %%
get_position_data("Q0.15_W0.4_D0.2_T0.005_wb1.json")
